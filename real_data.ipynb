# %%
import pandas as pd
from utils import discover_fds_with_chase, group_fds, compute_all_closures, compute_candidate_keys, find_prime_attributes, minimal_cover

# %% [markdown]
# ## Rider

# %%
rider = pd.read_csv('riders.csv')
rider.head()
# Out:
#    bib        rider_name         dob                   team  \
# 0    1     Tadej Pogacar  1998-09-21  UAE TEAM EMIRATES XRG
# 1    2      Joao Almeida  1998-08-05  UAE TEAM EMIRATES XRG
# 2    3  Jhonatan Narvaez  1997-03-04  UAE TEAM EMIRATES XRG
# 3    4       Nils Politt  1994-03-06  UAE TEAM EMIRATES XRG
# 4    5     Pavel Sivakov  1997-07-11  UAE TEAM EMIRATES XRG
#
#   rider_country_code rider_country_name team_country_code  \
# 0                SLO           Slovenia               UAE
# 1                POR           Portugal               UAE
# 2                ECU            Ecuador               UAE
# 3                GER            Germany               UAE
# 4                FRA             France               UAE
#
#       team_country_name
# 0  United Arab Emirates
# 1  United Arab Emirates
# 2  United Arab Emirates
# 3  United Arab Emirates
# 4  United Arab Emirates

# %%
fd_rider = discover_fds_with_chase(rider)
fd_rider = group_fds(fd_rider)

print("\nDiscovered Functional Dependencies:")
for lhs, rhs_set in fd_rider:
    print(f"{lhs} -> {rhs_set}")
# Out:
# Discovered Functional Dependencies:
# {'rider_name'} -> {'team', 'rider_country_name', 'dob', 'team_country_code', 'bib', 'team_country_name', 'rider_country_code'}
# {'bib'} -> {'team', 'rider_name', 'rider_country_name', 'dob', 'team_country_code', 'rider_country_code', 'team_country_name'}
# {'rider_country_name'} -> {'rider_country_code'}
# {'team', 'dob'} -> {'rider_country_code', 'rider_country_name'}
# {'rider_country_code'} -> {'rider_country_name'}
# {'team_country_code', 'rider_country_code', 'dob'} -> {'team'}
# {'rider_country_code', 'team_country_name', 'dob'} -> {'team'}
# {'team_country_code', 'rider_country_name', 'dob'} -> {'team'}
# {'team_country_name', 'rider_country_name', 'dob'} -> {'team'}
# {'team'} -> {'team_country_code', 'team_country_name'}
# {'team_country_name'} -> {'team_country_code'}
# {'team_country_code'} -> {'team_country_name'}

# %%
attributes_rider = rider.columns.to_list()

# %%
rider_all_closures = compute_all_closures(attributes_rider, fd_rider)

# %%
candidate_keys_rider = compute_candidate_keys(rider_all_closures, attributes_rider)

# %%
find_prime_attributes(candidate_keys_rider)
# Out:
# {'bib', 'rider_name'}

# %%
minimal_fds_rider = minimal_cover(fd_rider, p = 0.5)
for lhs, rhs in minimal_fds_rider:
    print(f"{lhs} -> {rhs}")
# Out:
# {'rider_name'} -> {'team_country_code', 'bib'}
# {'bib'} -> {'rider_country_code', 'rider_name', 'dob'}
# {'rider_country_name'} -> {'rider_country_code'}
# {'team', 'dob'} -> {'rider_country_name'}
# {'rider_country_code'} -> {'rider_country_name'}
# {'team_country_name', 'rider_country_name', 'dob'} -> {'team'}
# {'team'} -> {'team_country_name'}
# {'team_country_name'} -> {'team_country_code'}
# {'team_country_code'} -> {'team_country_name'}

# %% [markdown]
# ## Exits

# %%
exits = pd.read_csv('exits.csv')
exits.head()
# Out:
#    bib              name  stage reason
# 0  163     Bryan Coquard     14    DNS
# 1   66  Carlos Rodriguez     18    DNS
# 2  173          Cees Bol     12    DNS
# 3   93      Cyril Barthe     18    DNS
# 4   77  Danny Van Poppel     17    DNS

# %%
fd_exits = discover_fds_with_chase(exits)
fd_exits = group_fds(fd_exits)
print("\nDiscovered Functional Dependencies for exits.csv:")
for lhs, rhs_set in fd_exits:
    print(f"{lhs} -> {rhs_set}")
# Out:
# Discovered Functional Dependencies for exits.csv:
# {'name'} -> {'bib', 'stage', 'reason'}
# {'bib'} -> {'stage', 'name', 'reason'}

# %%
attributes_exits = exits.columns.to_list()
exits_all_closures = compute_all_closures(attributes_exits, fd_exits)
exits_all_closures
# Out:
# {('bib',): {'bib', 'name', 'reason', 'stage'},
#  ('name',): {'bib', 'name', 'reason', 'stage'},
#  ('stage',): {'stage'},
#  ('reason',): {'reason'},
#  ('bib', 'name'): {'bib', 'name', 'reason', 'stage'},
#  ('bib', 'stage'): {'bib', 'name', 'reason', 'stage'},
#  ('bib', 'reason'): {'bib', 'name', 'reason', 'stage'},
#  ('name', 'stage'): {'bib', 'name', 'reason', 'stage'},
#  ('name', 'reason'): {'bib', 'name', 'reason', 'stage'},
#  ('stage', 'reason'): {'reason', 'stage'},
#  ('bib', 'name', 'stage'): {'bib', 'name', 'reason', 'stage'},
#  ('bib', 'name', 'reason'): {'bib', 'name', 'reason', 'stage'},
#  ('bib', 'stage', 'reason'): {'bib', 'name', 'reason', 'stage'},
#  ('name', 'stage', 'reason'): {'bib', 'name', 'reason', 'stage'},
#  ('bib', 'name', 'stage', 'reason'): {'bib', 'name', 'reason', 'stage'}}

# %%
candidate_keys_exits = compute_candidate_keys(exits_all_closures, attributes_exits)

# %%
find_prime_attributes(candidate_keys_exits)
# Out:
# {'bib', 'name'}

# %%
minimal_fds_exits = minimal_cover(fd_exits, p = 0.5)
for lhs, rhs in minimal_fds_exits:
    print(f"{lhs} -> {rhs}")
# Out:
# {'name'} -> {'bib', 'reason'}
# {'bib'} -> {'stage', 'name'}

# %% [markdown]
# ## Individual

# %%
individual_results = pd.read_csv('individual_results.csv')
individual_results.head()
# Out:
#           day  rider  rank   time  bonus  penalty   start_location  \
# 0  2023-07-05    101     1  13991     10        0  Lille Métropole
# 1  2023-07-05     41     2  13991      6        0  Lille Métropole
# 2  2023-07-05    228     3  13991      4        0  Lille Métropole
# 3  2023-07-05    187     4  13991      0        0  Lille Métropole
# 4  2023-07-05    118     5  13991      0        0  Lille Métropole
#
#   start_country_code start_country_name  finish_location finish_country_code  \
# 0                FRA             France  Lille Métropole                 FRA
# 1                FRA             France  Lille Métropole                 FRA
# 2                FRA             France  Lille Métropole                 FRA
# 3                FRA             France  Lille Métropole                 FRA
# 4                FRA             France  Lille Métropole                 FRA
#
#   finish_country_name  length  type                name  \
# 0              France   184.9  flat    Jasper Philipsen
# 1              France   184.9  flat       Biniam Girmay
# 2              France   184.9  flat  Soren Waerenskjold
# 3              France   184.9  flat      Anthony Turgis
# 4              France   184.9  flat      Matteo Trentin
#
#                      team
# 0      ALPECIN-DECEUNINCK
# 1     INTERMARCHÉ - WANTY
# 2          UNO-X MOBILITY
# 3           TOTALENERGIES
# 4  TUDOR PRO CYCLING TEAM

# %%
fd_individual = discover_fds_with_chase(individual_results)
fd_individual = group_fds(fd_individual)
print("\nDiscovered Functional Dependencies for individual_results.csv:")
for lhs, rhs_set in fd_individual:
    print(f"{lhs} -> {rhs_set}")
# Out:
# Discovered Functional Dependencies for individual_results.csv:
# {'name', 'day'} -> {'penalty', 'bonus', 'time', 'rank'}
# {'day', 'rank'} -> {'penalty', 'bonus', 'time'}
# {'rider', 'day'} -> {'penalty', 'bonus', 'time', 'rank'}
# {'name', 'finish_location'} -> {'penalty', 'bonus', 'time', 'rank'}
# {'finish_location', 'rank'} -> {'penalty', 'bonus', 'time'}
# {'finish_location', 'rider'} -> {'penalty', 'bonus', 'time', 'rank'}
# {'rank', 'length'} -> {'bonus'}
# {'start_location', 'name'} -> {'penalty', 'bonus', 'time', 'rank'}
# {'name', 'time'} -> {'penalty', 'bonus', 'type'}
# {'start_location', 'rank'} -> {'penalty', 'bonus', 'time'}
# {'time', 'rank'} -> {'start_location', 'bonus', 'day', 'type', 'penalty', 'finish_location', 'length'}
# {'type', 'rank'} -> {'bonus'}
# {'start_location', 'rider'} -> {'penalty', 'bonus', 'time', 'rank'}
# {'time', 'rider'} -> {'penalty', 'bonus', 'type'}
# {'finish_location'} -> {'start_location', 'type', 'day', 'length'}
# {'start_location'} -> {'type', 'finish_location', 'day', 'length'}
# {'time', 'length'} -> {'start_location', 'finish_location', 'day'}
# set() -> {'finish_country_name', 'start_country_name', 'finish_country_code', 'start_country_code'}
# {'day'} -> {'start_location', 'type', 'finish_location', 'length'}
# {'rider'} -> {'name', 'team'}
# {'team', 'day', 'rank'} -> {'name', 'rider'}
# {'team', 'finish_location', 'rank'} -> {'name', 'rider'}
# {'start_location', 'team', 'rank'} -> {'name', 'rider'}
# {'team', 'time', 'rank'} -> {'name', 'rider'}
# {'bonus', 'time', 'team'} -> {'penalty'}
# {'rank', 'name', 'length'} -> {'penalty'}
# {'rank', 'rider', 'length'} -> {'penalty'}
# {'rank', 'team', 'length'} -> {'penalty'}
# {'name', 'time', 'length'} -> {'rank'}
# {'time', 'rider', 'length'} -> {'rank'}
# {'name'} -> {'team', 'rider'}
# {'length'} -> {'type'}

# %%
attributes_individual = individual_results.columns.to_list()
individual_all_closures = compute_all_closures(attributes_individual, fd_individual)
individual_all_closures
# Out:
# {('day',): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('rider',): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('rank',): {'finish_country_code',
#   'finish_country_name',
#   'rank',
#   'start_country_code',
#   'start_country_name'},
#  ('time',): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'time'},
#  ('bonus',): {'bonus',
#   'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name'},
#  ('penalty',): {'finish_country_code',
#   'finish_country_name',
#   'penalty',
#   'start_country_code',
#   'start_country_name'},
#  ('start_location',): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('start_country_code',): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name'},
#  ('start_country_name',): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name'},
#  ('finish_location',): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('finish_country_code',): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name'},
#  ('finish_country_name',): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name'},
#  ('length',): {'finish_country_code',
#   'finish_country_name',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'type'},
#  ('type',): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'type'},
#  ('name',): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('team',): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('day', 'rider'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'rank'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'time'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'bonus'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_country_code'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'finish_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'finish_country_code'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'finish_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'length'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'type'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'team'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('rider', 'rank'): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('rider', 'time'): {'bonus',
#   'finish_country_code',
#   'finish_country_name',
#   'name',
#   'penalty',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team',
#   'time',
#   'type'},
#  ('rider', 'bonus'): {'bonus',
#   'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('rider', 'penalty'): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'penalty',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('rider', 'start_location'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('rider', 'start_country_code'): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('rider', 'start_country_name'): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('rider', 'finish_location'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('rider', 'finish_country_code'): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('rider', 'finish_country_name'): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('rider', 'length'): {'finish_country_code',
#   'finish_country_name',
#   'length',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team',
#   'type'},
#  ('rider', 'type'): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team',
#   'type'},
#  ('rider', 'name'): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('rider', 'team'): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('rank', 'time'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('rank', 'bonus'): {'bonus',
#   'finish_country_code',
#   'finish_country_name',
#   'rank',
#   'start_country_code',
#   'start_country_name'},
#  ('rank', 'penalty'): {'finish_country_code',
#   'finish_country_name',
#   'penalty',
#   'rank',
#   'start_country_code',
#   'start_country_name'},
#  ('rank', 'start_location'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('rank', 'start_country_code'): {'finish_country_code',
#   'finish_country_name',
#   'rank',
#   'start_country_code',
#   'start_country_name'},
#  ('rank', 'start_country_name'): {'finish_country_code',
#   'finish_country_name',
#   'rank',
#   'start_country_code',
#   'start_country_name'},
#  ('rank', 'finish_location'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('rank', 'finish_country_code'): {'finish_country_code',
#   'finish_country_name',
#   'rank',
#   'start_country_code',
#   'start_country_name'},
#  ('rank', 'finish_country_name'): {'finish_country_code',
#   'finish_country_name',
#   'rank',
#   'start_country_code',
#   'start_country_name'},
#  ('rank', 'length'): {'bonus',
#   'finish_country_code',
#   'finish_country_name',
#   'length',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'type'},
#  ('rank', 'type'): {'bonus',
#   'finish_country_code',
#   'finish_country_name',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'type'},
#  ('rank', 'name'): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('rank', 'team'): {'finish_country_code',
#   'finish_country_name',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('time', 'bonus'): {'bonus',
#   'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'time'},
#  ('time', 'penalty'): {'finish_country_code',
#   'finish_country_name',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'time'},
#  ('time', 'start_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('time', 'start_country_code'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'time'},
#  ('time', 'start_country_name'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'time'},
#  ('time', 'finish_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('time', 'finish_country_code'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'time'},
#  ('time', 'finish_country_name'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'time'},
#  ('time', 'length'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('time', 'type'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'time',
#   'type'},
#  ('time', 'name'): {'bonus',
#   'finish_country_code',
#   'finish_country_name',
#   'name',
#   'penalty',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team',
#   'time',
#   'type'},
#  ('time', 'team'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'team',
#   'time'},
#  ('bonus', 'penalty'): {'bonus',
#   'finish_country_code',
#   'finish_country_name',
#   'penalty',
#   'start_country_code',
#   'start_country_name'},
#  ('bonus', 'start_location'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('bonus', 'start_country_code'): {'bonus',
#   'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name'},
#  ('bonus', 'start_country_name'): {'bonus',
#   'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name'},
#  ('bonus', 'finish_location'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('bonus', 'finish_country_code'): {'bonus',
#   'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name'},
#  ('bonus', 'finish_country_name'): {'bonus',
#   'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name'},
#  ('bonus', 'length'): {'bonus',
#   'finish_country_code',
#   'finish_country_name',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'type'},
#  ('bonus', 'type'): {'bonus',
#   'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'type'},
#  ('bonus', 'name'): {'bonus',
#   'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('bonus', 'team'): {'bonus',
#   'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('penalty', 'start_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('penalty', 'start_country_code'): {'finish_country_code',
#   'finish_country_name',
#   'penalty',
#   'start_country_code',
#   'start_country_name'},
#  ('penalty', 'start_country_name'): {'finish_country_code',
#   'finish_country_name',
#   'penalty',
#   'start_country_code',
#   'start_country_name'},
#  ('penalty', 'finish_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('penalty', 'finish_country_code'): {'finish_country_code',
#   'finish_country_name',
#   'penalty',
#   'start_country_code',
#   'start_country_name'},
#  ('penalty', 'finish_country_name'): {'finish_country_code',
#   'finish_country_name',
#   'penalty',
#   'start_country_code',
#   'start_country_name'},
#  ('penalty', 'length'): {'finish_country_code',
#   'finish_country_name',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'type'},
#  ('penalty', 'type'): {'finish_country_code',
#   'finish_country_name',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'type'},
#  ('penalty', 'name'): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'penalty',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('penalty', 'team'): {'finish_country_code',
#   'finish_country_name',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('start_location', 'start_country_code'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('start_location', 'start_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('start_location', 'finish_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('start_location', 'finish_country_code'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('start_location', 'finish_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('start_location', 'length'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('start_location', 'type'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('start_location', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('start_location', 'team'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('start_country_code', 'start_country_name'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name'},
#  ('start_country_code', 'finish_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('start_country_code', 'finish_country_code'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name'},
#  ('start_country_code', 'finish_country_name'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name'},
#  ('start_country_code', 'length'): {'finish_country_code',
#   'finish_country_name',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'type'},
#  ('start_country_code', 'type'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'type'},
#  ('start_country_code', 'name'): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('start_country_code', 'team'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('start_country_name', 'finish_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('start_country_name', 'finish_country_code'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name'},
#  ('start_country_name', 'finish_country_name'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name'},
#  ('start_country_name', 'length'): {'finish_country_code',
#   'finish_country_name',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'type'},
#  ('start_country_name', 'type'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'type'},
#  ('start_country_name', 'name'): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('start_country_name', 'team'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('finish_location', 'finish_country_code'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('finish_location', 'finish_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('finish_location', 'length'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('finish_location', 'type'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('finish_location', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('finish_location', 'team'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('finish_country_code', 'finish_country_name'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name'},
#  ('finish_country_code', 'length'): {'finish_country_code',
#   'finish_country_name',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'type'},
#  ('finish_country_code', 'type'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'type'},
#  ('finish_country_code', 'name'): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('finish_country_code', 'team'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('finish_country_name', 'length'): {'finish_country_code',
#   'finish_country_name',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'type'},
#  ('finish_country_name', 'type'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'type'},
#  ('finish_country_name', 'name'): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('finish_country_name', 'team'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('length', 'type'): {'finish_country_code',
#   'finish_country_name',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'type'},
#  ('length', 'name'): {'finish_country_code',
#   'finish_country_name',
#   'length',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team',
#   'type'},
#  ('length', 'team'): {'finish_country_code',
#   'finish_country_name',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'team',
#   'type'},
#  ('type', 'name'): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team',
#   'type'},
#  ('type', 'team'): {'finish_country_code',
#   'finish_country_name',
#   'start_country_code',
#   'start_country_name',
#   'team',
#   'type'},
#  ('name', 'team'): {'finish_country_code',
#   'finish_country_name',
#   'name',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'team'},
#  ('day', 'rider', 'rank'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'rider', 'time'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'rider', 'bonus'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'rider', 'penalty'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'rider', 'start_location'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'rider', 'start_country_code'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'rider', 'start_country_name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'rider', 'finish_location'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'rider', 'finish_country_code'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'rider', 'finish_country_name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'rider', 'length'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'rider', 'type'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'rider', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'rider', 'team'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'rank', 'time'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'rank', 'bonus'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'rank', 'penalty'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'rank', 'start_location'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'rank', 'start_country_code'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'rank', 'start_country_name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'rank', 'finish_location'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'rank', 'finish_country_code'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'rank', 'finish_country_name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'rank', 'length'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'rank', 'type'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'rank',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'rank', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'rank', 'team'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'time', 'bonus'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'time', 'penalty'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'time', 'start_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'time', 'start_country_code'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'time', 'start_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'time', 'finish_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'time', 'finish_country_code'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'time', 'finish_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'time', 'length'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'time', 'type'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'time',
#   'type'},
#  ('day', 'time', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'time', 'team'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'bonus', 'penalty'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_location'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_country_code'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_country_name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'finish_location'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'finish_country_code'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'finish_country_name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'length'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'type'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'bonus', 'team'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'penalty', 'start_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'start_country_code'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'start_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'finish_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'finish_country_code'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'finish_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'length'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'type'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'penalty', 'team'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'start_location', 'start_country_code'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_location', 'start_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_location', 'finish_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_location', 'finish_country_code'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_location', 'finish_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_location', 'length'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_location', 'type'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_location', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'start_location', 'team'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'start_country_code', 'start_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_country_code', 'finish_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_country_code', 'finish_country_code'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_country_code', 'finish_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_country_code', 'length'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_country_code', 'type'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_country_code', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'start_country_code', 'team'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'start_country_name', 'finish_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_country_name', 'finish_country_code'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_country_name', 'finish_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_country_name', 'length'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_country_name', 'type'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'start_country_name', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'start_country_name', 'team'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'finish_location', 'finish_country_code'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'finish_location', 'finish_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'finish_location', 'length'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'finish_location', 'type'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'finish_location', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'finish_location', 'team'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'finish_country_code', 'finish_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'finish_country_code', 'length'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'finish_country_code', 'type'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'finish_country_code', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'finish_country_code', 'team'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'finish_country_name', 'length'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'finish_country_name', 'type'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'finish_country_name', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'finish_country_name', 'team'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'length', 'type'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'length', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'length', 'team'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'type', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'type', 'team'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'name', 'team'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
# ...
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'penalty', 'finish_country_name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'penalty', 'length'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'penalty', 'type'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'penalty', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'bonus', 'penalty', 'team'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'bonus', 'start_location', 'start_country_code'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_location', 'start_country_name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_location', 'finish_location'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_location', 'finish_country_code'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_location', 'finish_country_name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_location', 'length'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_location', 'type'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_location', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'bonus', 'start_location', 'team'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'bonus', 'start_country_code', 'start_country_name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_country_code', 'finish_location'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_country_code', 'finish_country_code'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_country_code', 'finish_country_name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_country_code', 'length'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_country_code', 'type'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_country_code', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'bonus', 'start_country_code', 'team'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'bonus', 'start_country_name', 'finish_location'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_country_name', 'finish_country_code'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_country_name', 'finish_country_name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_country_name', 'length'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_country_name', 'type'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'start_country_name', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'bonus', 'start_country_name', 'team'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'bonus', 'finish_location', 'finish_country_code'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'finish_location', 'finish_country_name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'finish_location', 'length'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'finish_location', 'type'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'finish_location', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'bonus', 'finish_location', 'team'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'bonus', 'finish_country_code', 'finish_country_name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'finish_country_code', 'length'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'finish_country_code', 'type'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'finish_country_code', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'bonus', 'finish_country_code', 'team'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'bonus', 'finish_country_name', 'length'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'finish_country_name', 'type'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'finish_country_name', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'bonus', 'finish_country_name', 'team'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'bonus', 'length', 'type'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'bonus', 'length', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'bonus', 'length', 'team'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'bonus', 'type', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'bonus', 'type', 'team'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'bonus', 'name', 'team'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'penalty', 'start_location', 'start_country_code'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'start_location', 'start_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'start_location', 'finish_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'start_location', 'finish_country_code'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'start_location', 'finish_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'start_location', 'length'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'start_location', 'type'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'start_location', 'name'): {'bonus',
#   'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'name',
#   'penalty',
#   'rank',
#   'rider',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'time',
#   'type'},
#  ('day', 'penalty', 'start_location', 'team'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'team',
#   'type'},
#  ('day', 'penalty', 'start_country_code', 'start_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'start_country_code', 'finish_location'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'start_country_code', 'finish_country_code'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'start_country_code', 'finish_country_name'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ('day', 'penalty', 'start_country_code', 'length'): {'day',
#   'finish_country_code',
#   'finish_country_name',
#   'finish_location',
#   'length',
#   'penalty',
#   'start_country_code',
#   'start_country_name',
#   'start_location',
#   'type'},
#  ...}

# %%
individual_candidate_keys = compute_candidate_keys(individual_all_closures, attributes_individual)

# %%
find_prime_attributes(individual_candidate_keys)
# Out:
# {'day',
#  'finish_location',
#  'length',
#  'name',
#  'rank',
#  'rider',
#  'start_location',
#  'team',
#  'time'}

# %%
minimal_fds_individual = minimal_cover(fd_individual, p = 0.5)
for lhs, rhs in minimal_fds_individual:
    print(f"{lhs} -> {rhs}")
# Out:
# {'finish_location', 'rank'} -> {'penalty', 'time'}
# {'name', 'time'} -> {'type'}
# {'time', 'rank'} -> {'start_location'}
# {'type', 'rank'} -> {'bonus'}
# {'start_location', 'rider'} -> {'rank'}
# {'time', 'rider'} -> {'bonus'}
# {'finish_location'} -> {'start_location'}
# {'start_location'} -> {'day'}
# {'time', 'length'} -> {'day'}
# set() -> {'finish_country_name', 'start_country_name', 'finish_country_code', 'start_country_code'}
# {'day'} -> {'finish_location', 'length'}
# {'rider'} -> {'name'}
# {'team', 'time', 'rank'} -> {'name'}
# {'bonus', 'time', 'team'} -> {'penalty'}
# {'rank', 'team', 'length'} -> {'penalty'}
# {'name'} -> {'team', 'rider'}
# {'length'} -> {'type'}
